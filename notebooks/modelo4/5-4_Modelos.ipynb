# %% [markdown]
# # Notebook #5: Predicciones

# %%
# %load_ext autoreload
# %autoreload 2

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# Para realizar la evaluación del modelo
# -----------------------------------------------------------------------
from sklearn.model_selection import train_test_split,GridSearchCV

# Ignorar los warnings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings('ignore')

# Librería para el acceso a variables y funciones
# -----------------------------------------------------------------------
import sys
sys.path.append("../../")
from src import soporte_modelos as sm

# %% [markdown]
# - El primer paso consiste en cargar los datos ya estandarizados.

# %%
df = pd.read_pickle('../../datos/pickles_transformados/modelo4/df_estandarizado.pkl')

# %%
df.sample(5)
# Out:
#      Attrition       BusinessTravel           Department  \
# 1795         1  0.13106056483648038  0.17282729334555808
# 233          0  0.11542076233322036  0.17672634271099746
# 1348         0  0.14877177146265694  0.14709008935773735
# 240          0  0.30782275102857776  0.17254347069416912
# 1373         1  0.14620674092019734  0.15749158036008204
#
#                  Education        EducationField    Gender  \
# 1795   0.15641437050620086   0.16463938618925833  0.165511
# 233    0.06709429915023513    0.1080834739076019  0.161598
# 1348   0.18907633287428685   0.15921401169163316  0.157996
# 240   0.026641091219096334  0.061044555121819895  0.152229
# 1373   0.18857085168163376    0.1587321242030186   0.16348
#
#                  JobLevel   JobRole        MaritalStatus     StockOptionLevel  \
# 1795    0.153347775049478  0.160651  0.26253907360045464  0.15030739720637418
# 233   0.15791506820119353  0.114663  0.12344563012611341   0.2147328038766994
# 1348  0.12363403859567541  0.127243  0.12485598489986353  0.15440832714572503
# 240   0.10666273198242507  0.166308   0.1337679761854849  0.13882202497367233
# 1373  0.17760925607034775  0.170932  0.25204459898272935   0.1623888166336426
#
#       ...    PerformanceRating Age_standard DistanceFromHome_standard  \
# 1795  ...  0.16223682137186216     0.025385                 -0.881661
# 233   ...  0.25333013640238705    -0.306407                  0.478500
# 1348  ...  0.16086867640948269     1.794947                  0.602151
# 240   ...  0.12968993065626072    -0.748798                 -0.634359
# 1373  ...  0.17364414274446066    -1.965372                 -0.139755
#
#      MonthlyIncome_standard NumCompaniesWorked_standard  \
# 1795              -0.299689                    0.532781
# 233               -0.882781                   -0.675912
# 1348              -0.631801                   -0.273014
# 240               -0.150542                   -0.675912
# 1373               2.026326                   -0.675912
#
#      PercentSalaryHike_standard  TotalWorkingYears_standard  \
# 1795                  -0.051264                   -0.010680
# 233                    1.324338                   -0.408243
# 1348                  -0.876625                    0.254361
# 240                    0.498977                   -1.335888
# 1373                   1.599459                   -1.335888
#
#       YearsAtCompany_standard  YearsSinceLastPromotion_standard  \
# 1795                -1.002756                         -0.689424
# 233                  0.209056                         -0.689424
# 1348                 0.035940                          0.626229
# 240                 -1.002756                         -0.689424
# 1373                -1.002756                         -0.360511
#
#       YearsWithCurrManager_standard
# 1795                      -1.152339
# 233                        0.556339
# 1348                       0.271560
# 240                       -1.152339
# 1373                      -1.152339
#
# [5 rows x 25 columns]

# %% [markdown]
# - Nos aseguramos de que todo el conjunto sea de formato numérico.

# %%
df = df.astype(float)

# %% [markdown]
# - Separamos la "X" y la "y", donde la X será el cojunto de datos sin la variable respuesta, y la "y" será solamente la variable respuesta, en este caso, "Attrition".

# %%
X = df.drop("Attrition", axis = 1)
y = df[["Attrition"]]
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=42)

# %% [markdown]
# - Definimos un diccionario de hiperparámetros:

# %%
parametros_default = {
            "tree": {
                'max_depth': [3, 5, 10],
                'min_samples_split': [2, 10, 15],
                'min_samples_leaf': [1, 4, 8]
            },
            "random_forest": {
                'n_estimators': [50, 100, 200],
                'max_depth': [2, 6, 8, 20, 12, 16],
                'min_samples_split': [2, 5, 10],
                'min_samples_leaf': [4, 6, 8]
            },
            "gradient_boosting": {
                'n_estimators': [100, 200],
                'learning_rate': [0.01, 0.1, 0.2],
                'max_depth': [3, 4, 5],
                'min_samples_split': [2, 5, 10],
                'min_samples_leaf': [1, 2, 4],
                'subsample': [0.8, 1.0]
            },
            "xgboost": {
                'n_estimators': [100, 200],
                'learning_rate': [0.01, 0.05, 0.1],
                'max_depth': [5, 7, 9],
                'min_child_weight': [1, 3, 5],
                'subsample': [0.8, 1.0],
                'colsample_bytree': [0.8, 1.0]
            }}

# %% [markdown]
# - Instanciamos la clase "AnalisisModelosClasificacion".

# %%
analisis_mod_clas = sm.AnalisisModelosClasificacion(df, "Attrition")

# %% [markdown]
# - Y aplicamos los modelos: regresión logística, Decision Tree, Random Forest, Gradient Boost y XGBoost.

# %%
df_lg = analisis_mod_clas.ajustar_modelo("logistic_regression")
df_lg = analisis_mod_clas.calcular_metricas("logistic_regression")
df_lg["modelo"] = "logistic_regression"
df_lg
# Out:
#        accuracy  precision    recall        f1     kappa       auc  \
# train  0.706313   0.703243  0.706313  0.703486  0.384749  0.774252
# test   0.695946   0.692849  0.695946  0.693589  0.362178  0.759427
#
#        time_seconds  n_jobs  tiempo_computacion(segundos)  nucleos_usados  \
# train      0.001805     NaN                           NaN             NaN
# test            NaN     NaN                      0.001805             NaN
#
#                     modelo
# train  logistic_regression
# test   logistic_regression

# %%
df_tree = analisis_mod_clas.ajustar_modelo("tree", param_grid=parametros_default["tree"])
df_tree = analisis_mod_clas.calcular_metricas("tree")
df_tree["modelo"] = "tree"
df_tree
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# El mejor modelo es DecisionTreeClassifier(max_depth=10, min_samples_leaf=4, min_samples_split=15,
#                        random_state=42)
#        accuracy  precision    recall        f1     kappa       auc  \
# train  0.864149   0.865538  0.864149  0.862534  0.714577  0.939556
# test   0.702703   0.699346  0.702703  0.699843  0.374715  0.717791
#
#        time_seconds  n_jobs  tiempo_computacion(segundos)  nucleos_usados  \
# train      0.002773     8.0                           NaN             NaN
# test            NaN     NaN                      0.002773             8.0
#
#       modelo
# train   tree
# test    tree

# %%
df_rf = analisis_mod_clas.ajustar_modelo("random_forest", param_grid=parametros_default["random_forest"])
df_rf = analisis_mod_clas.calcular_metricas("random_forest")
df_rf["modelo"] = "random_forest"
df_rf
# Out:
# Fitting 5 folds for each of 162 candidates, totalling 810 fits
# El mejor modelo es RandomForestClassifier(max_depth=20, min_samples_leaf=4, min_samples_split=10,
#                        n_estimators=200, n_jobs=-1, random_state=42)
#        accuracy  precision    recall        f1     kappa       auc  \
# train  0.970688   0.970902  0.970688  0.970610  0.939232  0.997445
# test   0.808559   0.810932  0.808559  0.804285  0.591275  0.880680
#
#        time_seconds  n_jobs  tiempo_computacion(segundos)  nucleos_usados  \
# train      0.056098    -1.0                           NaN             NaN
# test            NaN     NaN                      0.056098            -1.0
#
#               modelo
# train  random_forest
# test   random_forest

# %%
df_gb = analisis_mod_clas.ajustar_modelo("gradient_boosting", param_grid=parametros_default["gradient_boosting"])
df_gb = analisis_mod_clas.calcular_metricas("gradient_boosting")
df_gb["modelo"] = "gradient_boost"
df_gb
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# El mejor modelo es GradientBoostingClassifier(learning_rate=0.2, max_depth=5, n_estimators=200,
#                            random_state=42)
#        accuracy  precision    recall        f1     kappa       auc  \
# train  1.000000   1.000000  1.000000  1.000000  1.000000  1.000000
# test   0.869369   0.869013  0.869369  0.868732  0.727163  0.936054
#
#        time_seconds  n_jobs  tiempo_computacion(segundos)  nucleos_usados  \
# train      0.008559     8.0                           NaN             NaN
# test            NaN     NaN                      0.008559             8.0
#
#                modelo
# train  gradient_boost
# test   gradient_boost

# %%
df_xgb = analisis_mod_clas.ajustar_modelo("xgboost", param_grid=parametros_default["xgboost"])
df_xgb = analisis_mod_clas.calcular_metricas("xgboost")
df_xgb["modelo"] = "x_gradient_boost"
df_xgb
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# El mejor modelo es XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=1.0, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)
#        accuracy  precision    recall        f1     kappa       auc  \
# train  1.000000   1.000000  1.000000  1.000000  1.000000  1.000000
# test   0.864865   0.864968  0.864865  0.863735  0.716276  0.931055
#
#        time_seconds  n_jobs  tiempo_computacion(segundos)  nucleos_usados  \
# train      0.005478     NaN                           NaN             NaN
# test            NaN     NaN                      0.005478             NaN
#
#                  modelo
# train  x_gradient_boost
# test   x_gradient_boost

# %% [markdown]
# ## Análisis de Métricas de los Modelos
#
# - Nos interesa priorizar el recall, que es lo mismo que decir que, daremos prioridad a los Verdaderos Positivos.
#
# - Consecuentemente, minimizaremos los Falsos Negativos, es decir, preferimos que el modelo nos diga que un empleado se marchará de la empresa aunque finalmente no sea así, pero queremos evitar el error (Falso Negativo) de decir que se queda cuando finalmente se acabará yendo.

# %%
df_completo = pd.concat([df_lg, df_tree, df_rf, df_gb, df_xgb])
df_completo.reset_index(drop=True, inplace=True)
df_completo.style.apply(sal.color_filas_por_modelo, axis = 1)
# Out:
# <style type="text/css">
# #T_2b52d_row0_col0, #T_2b52d_row0_col1, #T_2b52d_row0_col2, #T_2b52d_row0_col3, #T_2b52d_row0_col4, #T_2b52d_row0_col5, #T_2b52d_row0_col6, #T_2b52d_row0_col7, #T_2b52d_row0_col8, #T_2b52d_row0_col9, #T_2b52d_row0_col10, #T_2b52d_row1_col0, #T_2b52d_row1_col1, #T_2b52d_row1_col2, #T_2b52d_row1_col3, #T_2b52d_row1_col4, #T_2b52d_row1_col5, #T_2b52d_row1_col6, #T_2b52d_row1_col7, #T_2b52d_row1_col8, #T_2b52d_row1_col9, #T_2b52d_row1_col10 {
#   background-color: #b3d1ff;
#   color: black;
# }
# #T_2b52d_row2_col0, #T_2b52d_row2_col1, #T_2b52d_row2_col2, #T_2b52d_row2_col3, #T_2b52d_row2_col4, #T_2b52d_row2_col5, #T_2b52d_row2_col6, #T_2b52d_row2_col7, #T_2b52d_row2_col8, #T_2b52d_row2_col9, #T_2b52d_row2_col10, #T_2b52d_row3_col0, #T_2b52d_row3_col1, #T_2b52d_row3_col2, #T_2b52d_row3_col3, #T_2b52d_row3_col4, #T_2b52d_row3_col5, #T_2b52d_row3_col6, #T_2b52d_row3_col7, #T_2b52d_row3_col8, #T_2b52d_row3_col9, #T_2b52d_row3_col10 {
#   background-color: #e6b3e0;
#   color: black;
# }
# #T_2b52d_row4_col0, #T_2b52d_row4_col1, #T_2b52d_row4_col2, #T_2b52d_row4_col3, #T_2b52d_row4_col4, #T_2b52d_row4_col5, #T_2b52d_row4_col6, #T_2b52d_row4_col7, #T_2b52d_row4_col8, #T_2b52d_row4_col9, #T_2b52d_row4_col10, #T_2b52d_row5_col0, #T_2b52d_row5_col1, #T_2b52d_row5_col2, #T_2b52d_row5_col3, #T_2b52d_row5_col4, #T_2b52d_row5_col5, #T_2b52d_row5_col6, #T_2b52d_row5_col7, #T_2b52d_row5_col8, #T_2b52d_row5_col9, #T_2b52d_row5_col10 {
#   background-color: #c2f0c2;
#   color: black;
# }
# #T_2b52d_row6_col0, #T_2b52d_row6_col1, #T_2b52d_row6_col2, #T_2b52d_row6_col3, #T_2b52d_row6_col4, #T_2b52d_row6_col5, #T_2b52d_row6_col6, #T_2b52d_row6_col7, #T_2b52d_row6_col8, #T_2b52d_row6_col9, #T_2b52d_row6_col10, #T_2b52d_row7_col0, #T_2b52d_row7_col1, #T_2b52d_row7_col2, #T_2b52d_row7_col3, #T_2b52d_row7_col4, #T_2b52d_row7_col5, #T_2b52d_row7_col6, #T_2b52d_row7_col7, #T_2b52d_row7_col8, #T_2b52d_row7_col9, #T_2b52d_row7_col10 {
row2_col8" class="data row2 col8" >nan</td>
#       <td id="T_2b52d_row2_col9" class="data row2 col9" >nan</td>
#       <td id="T_2b52d_row2_col10" class="data row2 col10" >tree</td>
#     </tr>
#     <tr>
#       <th id="T_2b52d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2b52d_row3_col0" class="data row3 col0" >0.702703</td>
#       <td id="T_2b52d_row3_col1" class="data row3 col1" >0.699346</td>
#       <td id="T_2b52d_row3_col2" class="data row3 col2" >0.702703</td>
#       <td id="T_2b52d_row3_col3" class="data row3 col3" >0.699843</td>
#       <td id="T_2b52d_row3_col4" class="data row3 col4" >0.374715</td>
#       <td id="T_2b52d_row3_col5" class="data row3 col5" >0.717791</td>
#       <td id="T_2b52d_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_2b52d_row3_col7" class="data row3 col7" >nan</td>
#       <td id="T_2b52d_row3_col8" class="data row3 col8" >0.002773</td>
#       <td id="T_2b52d_row3_col9" class="data row3 col9" >8.000000</td>
#       <td id="T_2b52d_row3_col10" class="data row3 col10" >tree</td>
#     </tr>
#     <tr>
#       <th id="T_2b52d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2b52d_row4_col0" class="data row4 col0" >0.970688</td>
#       <td id="T_2b52d_row4_col1" class="data row4 col1" >0.970902</td>
#       <td id="T_2b52d_row4_col2" class="data row4 col2" >0.970688</td>
#       <td id="T_2b52d_row4_col3" class="data row4 col3" >0.970610</td>
#       <td id="T_2b52d_row4_col4" class="data row4 col4" >0.939232</td>
#       <td id="T_2b52d_row4_col5" class="data row4 col5" >0.997445</td>
#       <td id="T_2b52d_row4_col6" class="data row4 col6" >0.056098</td>
#       <td id="T_2b52d_row4_col7" class="data row4 col7" >-1.000000</td>
#       <td id="T_2b52d_row4_col8" class="data row4 col8" >nan</td>
#       <td id="T_2b52d_row4_col9" class="data row4 col9" >nan</td>
#       <td id="T_2b52d_row4_col10" class="data row4 col10" >random_forest</td>
#     </tr>
#     <tr>
#       <th id="T_2b52d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2b52d_row5_col0" class="data row5 col0" >0

# %% [markdown]
# - Por las métricas, el Gradient Boost es nuestro modelo con las mejores métricas, aunque con un overfitting significativo. De cerca el XGBoost, que por el tiempo inferior de cómputo sería nuestro mejor modelo.

# %% [markdown]
# ## Representaciones gráficas de los modelos
#
# - Como complemento a las métricas anteriores, podemos visualizar los resultados obtenidos de nuestros modelos:

# %%
analisis_mod_clas.shap_plots(["logistic_regression", "tree", "random_forest", "gradient_boosting", "xgboost"], plot_size=(15, 15), figsize=(10, 5))

# %%
analisis_mod_clas.matrices_confusion(["logistic_regression", "tree", "random_forest", "gradient_boosting", "xgboost"], figsize=(15,5))

# %%
analisis_mod_clas.curvas_roc_combinadas(["logistic_regression", "tree", "random_forest", "gradient_boosting", "xgboost"])

# %% [markdown]
# La curva ROC es una representación visual del rendimiento del modelo en todos los umbrales. La curva ROC se dibuja calculando la tasa de verdaderos positivos (TPR) y una tasa de falsos positivos (FPR) en cada umbral posible. Un modelo perfecto, tiene en algún umbral tiene una TPR de 1.0 y una FPR de 0.0.
#
# El área bajo la curva ROC (AUC) representa la probabilidad de que el modelo, si se da un ejemplo positivo y negativo elegido al azar, clasificará el positivo mayor que el negativo. El modelo perfecto anterior, que contiene un cuadrado con lados de longitud 1, tiene un área bajo la curva (AUC) de 1.0. Esto significa que hay un 100% de probabilidades de que el modelo clasificará de manera correcta un ejemplo positivo elegido al azar más alto que un ejemplo negativo elegido al azar.
