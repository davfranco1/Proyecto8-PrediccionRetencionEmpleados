# %% [markdown]
# # Notebook #4: Estandización

# %%
# %load_ext autoreload
# %autoreload 2

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np
import pickle
from collections import Counter
pd.set_option('display.max_columns', None)

# Feature scaling
# -----------------------------------------------------------------------
from sklearn.preprocessing import RobustScaler, MinMaxScaler, Normalizer, StandardScaler
from imblearn.under_sampling import TomekLinks
from imblearn.over_sampling import SMOTENC
from sklearn.model_selection import train_test_split


# Librería para el acceso a variables y funciones
# -----------------------------------------------------------------------
import sys
sys.path.append("../../")
from src import soporte_scaling as ss
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# - Como primer paso, cargaremos los datos.

# %%
df = pd.read_pickle('../../datos/pickles_transformados/modelo5/df_sinoutliers.pkl')
df.head()
# Out:
#    Age Attrition     BusinessTravel           Department  DistanceFromHome  \
# 0   51         0  0.159846547314578    0.159846547314578                 6
# 1   31         1  0.159846547314578    0.159846547314578                10
# 2   32         0  0.579923273657289    0.579923273657289                17
# 3   38         0  0.159846547314578  0.38661551577152603                 2
# 4   32         0  0.079923273657289   0.2899616368286445                10
#
#            Education       EducationField               Gender  \
# 0  0.159846547314578    0.159846547314578    0.159846547314578
# 1  0.159846547314578    0.079923273657289    0.079923273657289
# 2  0.159846547314578    0.159846547314578    0.159846547314578
# 3  0.159846547314578  0.38661551577152603    0.079923273657289
# 4  0.579923273657289    0.159846547314578  0.05328218243819267
#
#               JobLevel            JobRole        MaritalStatus  MonthlyIncome  \
# 0    0.159846547314578  0.159846547314578    0.159846547314578         131160
# 1    0.079923273657289  0.159846547314578    0.159846547314578          41890
# 2    0.159846547314578  0.159846547314578    0.079923273657289         193280
# 3    0.159846547314578  0.159846547314578  0.05328218243819267          83210
# 4  0.38661551577152603  0.079923273657289    0.579923273657289          23420
#
#    NumCompaniesWorked  PercentSalaryHike   StockOptionLevel  \
# 0                 1.0                 11  0.159846547314578
# 1                 0.0                 23  0.159846547314578
# 2                 1.0                 15  0.159846547314578
# 3                 3.0                 11  0.079923273657289
# 4                 4.0                 12  0.159846547314578
#
#    TotalWorkingYears TrainingTimesLastYear  YearsAtCompany  \
# 0                1.0     0.159846547314578               1
# 1                6.0     0.159846547314578               5
# 2                5.0     0.159846547314578               5
# 3               13.0     0.159846547314578               8
# 4                9.0     0.079923273657289               6
#
#    YearsSinceLastPromotion  YearsWithCurrManager EnvironmentSatisfaction  \
# 0                        0                     0       0.159846547314578
# 1                        1                     4       0.079923273657289
# 2                        0                     3       0.159846547314578
# 3                        7                     5       0.159846547314578
# 4                        0                     4       0.079923273657289
#
#      JobSatisfaction    WorkLifeBalance       JobInvolvement  \
# 0  0.159846547314578  0.159846547314578    0.159846547314578
# 1  0.159846547314578  0.159846547314578    0.159846547314578
# 2  0.579923273657289  0.159846547314578    0.079923273657289
# 3  0.079923273657289  0.159846547314578    0.579923273657289
# 4  0.159846547314578  0.079923273657289  0.05328218243819267
#
#      PerformanceRating
# 0    0.159846547314578
# 1    0.159846547314578
# 2    0.079923273657289
# 3  0.05328218243819267
# 4   0.0399616368286445

# %% [markdown]
# - Separamos las columnas a las que se va a aplicar la estandarización, que son las numéricas.

# %%
col_numericas = df.select_dtypes(include=np.number).columns
col_numericas
# Out:
# Index(['Age', 'DistanceFromHome', 'MonthlyIncome', 'NumCompaniesWorked',
#        'PercentSalaryHike', 'TotalWorkingYears', 'YearsAtCompany',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# - Y aplicamos los 4 escaladores con los que contamos:

# %%
df_escaladores_graf = ss.aplicar_escaladores(df, ['Age', 'DistanceFromHome', 'MonthlyIncome', 'NumCompaniesWorked',
       'PercentSalaryHike', 'TotalWorkingYears', 'YearsAtCompany',
       'YearsSinceLastPromotion', 'YearsWithCurrManager'], [RobustScaler(), MinMaxScaler(), StandardScaler(), Normalizer()])

# %%
df_escaladores_graf.head(5)
# Out:
#    Age Attrition     BusinessTravel           Department  DistanceFromHome  \
# 0   51         0  0.159846547314578    0.159846547314578                 6
# 1   31         1  0.159846547314578    0.159846547314578                10
# 2   32         0  0.579923273657289    0.579923273657289                17
# 3   38         0  0.159846547314578  0.38661551577152603                 2
# 4   32         0  0.079923273657289   0.2899616368286445                10
#
#            Education       EducationField               Gender  \
# 0  0.159846547314578    0.159846547314578    0.159846547314578
# 1  0.159846547314578    0.079923273657289    0.079923273657289
# 2  0.159846547314578    0.159846547314578    0.159846547314578
# 3  0.159846547314578  0.38661551577152603    0.079923273657289
# 4  0.579923273657289    0.159846547314578  0.05328218243819267
#
#               JobLevel            JobRole        MaritalStatus  MonthlyIncome  \
# 0    0.159846547314578  0.159846547314578    0.159846547314578         131160
# 1    0.079923273657289  0.159846547314578    0.159846547314578          41890
# 2    0.159846547314578  0.159846547314578    0.079923273657289         193280
# 3    0.159846547314578  0.159846547314578  0.05328218243819267          83210
# 4  0.38661551577152603  0.079923273657289    0.579923273657289          23420
#
#    NumCompaniesWorked  PercentSalaryHike   StockOptionLevel  \
# 0                 1.0                 11  0.159846547314578
# 1                 0.0                 23  0.159846547314578
# 2                 1.0                 15  0.159846547314578
# 3                 3.0                 11  0.079923273657289
# 4                 4.0                 12  0.159846547314578
#
#    TotalWorkingYears TrainingTimesLastYear  YearsAtCompany  \
# 0                1.0     0.159846547314578               1
# 1                6.0     0.159846547314578               5
# 2                5.0     0.159846547314578               5
# 3               13.0     0.159846547314578               8
# 4                9.0     0.079923273657289               6
#
#    YearsSinceLastPromotion  YearsWithCurrManager EnvironmentSatisfaction  \
# 0                        0                     0       0.159846547314578
# 1                        1                     4       0.079923273657289
# 2                        0                     3       0.159846547314578
# 3                        7                     5       0.159846547314578
# 4                        0                     4       0.079923273657289
#
#      JobSatisfaction    WorkLifeBalance       JobInvolvement  \
# 0  0.159846547314578  0.159846547314578    0.159846547314578
# 1  0.159846547314578  0.159846547314578    0.159846547314578
# 2  0.579923273657289  0.159846547314578    0.079923273657289
# 3  0.079923273657289  0.159846547314578    0.579923273657289
# 4  0.159846547314578  0.079923273657289  0.05328218243819267
#
#      PerformanceRating  Age_robust  DistanceFromHome_robust  \
# 0    0.159846547314578    1.333333                -0.083333
# 1    0.159846547314578   -0.333333                 0.250000
# 2    0.079923273657289   -0.250000                 0.833333
# 3  0.05328218243819267    0.250000                -0.416667
# 4   0.0399616368286445   -0.250000                 0.250000
#
#    MonthlyIncome_robust  NumCompaniesWorked_robust  PercentSalaryHike_robust  \
# 0              1.506673                  -0.333333                 -0.500000
# 1             -0.131083                  -0.666667                  1.500000
# 2              2.646333                  -0.333333                  0.166667
# 3              0.626978                   0.333333                 -0.500000
# 4             -0.469935                   0.666667                 -0.333333
#
#    TotalWorkingYears_robust  YearsAtCompany_robust  \
# 0                 -1.000000              -0.666667
# 1                 -0.444444               0.000000
# 2                 -0.555556               0.000000
# 3                  0.333333               0.500000
# 4                 -0.111111               0.166667
#
#    YearsSinceLastPromotion_robust  YearsWithCurrManager_robust  Age_minmax  \
# 0                            -0.5                         -0.6    0.785714
# 1                             0.0                          0.2    0.309524
# 2                            -0.5                          0.0    0.333333
# 3                             3.0                          0.4    0.476190
# 4                            -0.5                          0.2    0.333333
#
#    DistanceFromHome_minmax  MonthlyIncome_minmax  NumCompaniesWorked_minmax  \
# 0                 0.178571              0.637546                   0.111111
# 1                 0.321429              0.167457                   0.000000
# 2                 0.571429              0.964666                   0.111111
# 3                 0.035714              0.385045                   0.333333
# 4                 0.321429              0.070195                   0.444444
#
#    PercentSalaryHike_minmax  TotalWorkingYears_minmax  YearsAtCompany_minmax  \
# 0                  0.000000                  0.026316               0.027027
# 1                  0.857143                  0.157895               0.135135
# 2                  0.285714                  0.131579               0.135135
# 3                  0.000000                  0.342105               0.216216
# 4                  0.071429                  0.236842               0.162162
#
#    YearsSinceLastPromotion_minmax  YearsWithCurrManager_minmax  Age_standard  \
# 0                        0.000000                     0.000000      1.582686
# 1                        0.066667                     0.235294     -0.636213
# 2                        0.000000                     0.176471     -0.525268
# 3                        0.466667                     0.294118      0.140401
# 4                        0.000000                     0.235294     -0.525268
#
#    DistanceFromHome_standard  MonthlyIncome_standard  \
# 0                  -0.385842                1.414871
# 1                   0.108905               -0.489203
# 2                   0.974713                2.739852
# 3                  -0.880589                0.392127
# 4                   0.108905               -0.883157
#
#    NumCompaniesWorked_standard  PercentSalaryHike_standard  \
# 0                    -0.675545                   -1.150205
# 1                    -1.078840                    2.148577
# 2                    -0.675545                   -0.050611
# 3                     0.131045                   -1.150205
# 4                     0.534340                   -0.875307
#
#    TotalWorkingYears_standard  YearsAtCompany_standard  \
# 0                   -1.341939                -1.007981
# 1                   -0.673216                -0.307328
# 2                   -0.806961                -0.307328
# 3                    0.262997                 0.218162
# 4                   -0.271982                -0.132165
#
#    YearsSinceLastPromotion_standard  YearsWithCurrManager_standard  \
# 0                         -0.689743                      -1.153463
# 1                         -0.359179                      -0.008689
# 2                         -0.689743                      -0.294883
# 3                          1.624206                       0.277504
# 4                         -0.689743                      -0.008689
#
#    Age_normalizer  DistanceFromHome_normalizer  MonthlyIncome_normalizer  \
# 0        0.000389                     0.000046                  1.000000
# 1        0.000740                     0.000239                  1.000000
# 2        0.000166                     0.000088                  1.000000
# 3        0.000457                     0.000024                  1.000000
# 4        0.001366                     0.000427                  0.999999
#
#    NumCompaniesWorked_normalizer  PercentSalaryHike_normalizer  \
# 0                       0.000008                      0.000084
# 1                       0.000000                      0.000549
# 2                       0.000005                      0.000078
# 3                       0.000036                      0.000132
# 4                       0.000171                      0.000512
#
#    TotalWorkingYears_normalizer  YearsAtCompany_normalizer  \
# 0                      0.000008                   0.000008
# 1                      0.000143                   0.000119
# 2                      0.000026                   0.000026
# 3                      0.000156                   0.000096
# 4                      0.000384                   0.000256
#
#    YearsSinceLastPromotion_normalizer  YearsWithCurrManager_normalizer
# 0                            0.000000                         0.000000
# 1                            0.000024                         0.000095
# 2                            0.000000                         0.000016
# 3                            0.000084                         0.000060
# 4                            0.000000                         0.000171

# %% [markdown]
# - Los representamos visualmente:

# %%
ss.graficar_escaladores(df_escaladores_graf, ['Age', 'DistanceFromHome', 'MonthlyIncome', 'NumCompaniesWorked',
       'PercentSalaryHike', 'TotalWorkingYears', 'YearsAtCompany',
       'YearsSinceLastPromotion', 'YearsWithCurrManager'], ['Age_robust',
       'DistanceFromHome_robust', 'MonthlyIncome_robust',
       'NumCompaniesWorked_robust', 'PercentSalaryHike_robust',
       'TotalWorkingYears_robust', 'YearsAtCompany_robust',
       'YearsSinceLastPromotion_robust', 'YearsWithCurrManager_robust',
       'Age_minmax', 'DistanceFromHome_minmax', 'MonthlyIncome_minmax',
       'NumCompaniesWorked_minmax', 'PercentSalaryHike_minmax',
       'TotalWorkingYears_minmax', 'YearsAtCompany_minmax',
       'YearsSinceLastPromotion_minmax', 'YearsWithCurrManager_minmax',
       'Age_standard', 'DistanceFromHome_standard', 'MonthlyIncome_standard',
       'NumCompaniesWorked_standard', 'PercentSalaryHike_standard',
       'TotalWorkingYears_standard', 'YearsAtCompany_standard',
       'YearsSinceLastPromotion_standard', 'YearsWithCurrManager_standard',
       'Age_normalizer', 'DistanceFromHome_normalizer',
       'MonthlyIncome_normalizer', 'NumCompaniesWorked_normalizer',
       'PercentSalaryHike_normalizer', 'TotalWorkingYears_normalizer',
       'YearsAtCompany_normalizer', 'YearsSinceLastPromotion_normalizer',
       'YearsWithCurrManager_normalizer'])

# %% [markdown]
# - Nos quedaremos con el StandardScaler, dado que, en las gráficas no se observan grandes diferencias y, lo que interesa en este caso es minimizar -"suavizar"- las diferencias.

# %%
df_standard = ss.aplicar_escaladores(df, ['Age', 'DistanceFromHome', 'MonthlyIncome', 'NumCompaniesWorked',
       'PercentSalaryHike', 'TotalWorkingYears', 'YearsAtCompany',
       'YearsSinceLastPromotion', 'YearsWithCurrManager'], [StandardScaler()])
df_standard.head(1)
# Out:
#    Age Attrition     BusinessTravel         Department  DistanceFromHome  \
# 0   51         0  0.159846547314578  0.159846547314578                 6
#
#            Education     EducationField             Gender           JobLevel  \
# 0  0.159846547314578  0.159846547314578  0.159846547314578  0.159846547314578
#
#              JobRole      MaritalStatus  MonthlyIncome  NumCompaniesWorked  \
# 0  0.159846547314578  0.159846547314578         131160                 1.0
#
#    PercentSalaryHike   StockOptionLevel  TotalWorkingYears  \
# 0                 11  0.159846547314578                1.0
#
#   TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# 0     0.159846547314578               1                        0
#
#    YearsWithCurrManager EnvironmentSatisfaction    JobSatisfaction  \
# 0                     0       0.159846547314578  0.159846547314578
#
#      WorkLifeBalance     JobInvolvement  PerformanceRating  Age_standard  \
# 0  0.159846547314578  0.159846547314578  0.159846547314578      1.582686
#
#    DistanceFromHome_standard  MonthlyIncome_standard  \
# 0                  -0.385842                1.414871
#
#    NumCompaniesWorked_standard  PercentSalaryHike_standard  \
# 0                    -0.675545                   -1.150205
#
#    TotalWorkingYears_standard  YearsAtCompany_standard  \
# 0                   -1.341939                -1.007981
#
#    YearsSinceLastPromotion_standard  YearsWithCurrManager_standard
# 0                         -0.689743                      -1.153463

# %% [markdown]
# - Eliminamos las columnas originales.

# %%
df_standard.drop(columns = ['Age', 'DistanceFromHome', 'MonthlyIncome', 'NumCompaniesWorked',
       'PercentSalaryHike', 'TotalWorkingYears', 'YearsAtCompany',
       'YearsSinceLastPromotion', 'YearsWithCurrManager'], inplace=True)
df_standard.head(1)
# Out:
#   Attrition     BusinessTravel         Department          Education  \
# 0         0  0.159846547314578  0.159846547314578  0.159846547314578
#
#       EducationField             Gender           JobLevel            JobRole  \
# 0  0.159846547314578  0.159846547314578  0.159846547314578  0.159846547314578
#
#        MaritalStatus   StockOptionLevel TrainingTimesLastYear  \
# 0  0.159846547314578  0.159846547314578     0.159846547314578
#
#   EnvironmentSatisfaction    JobSatisfaction    WorkLifeBalance  \
# 0       0.159846547314578  0.159846547314578  0.159846547314578
#
#       JobInvolvement  PerformanceRating  Age_standard  \
# 0  0.159846547314578  0.159846547314578      1.582686
#
#    DistanceFromHome_standard  MonthlyIncome_standard  \
# 0                  -0.385842                1.414871
#
#    NumCompaniesWorked_standard  PercentSalaryHike_standard  \
# 0                    -0.675545                   -1.150205
#
#    TotalWorkingYears_standard  YearsAtCompany_standard  \
# 0                   -1.341939                -1.007981
#
#    YearsSinceLastPromotion_standard  YearsWithCurrManager_standard
# 0                         -0.689743                      -1.153463

# %% [markdown]
# # Balanceo
#
# - Como hemos visto durante el EDA, existe un desbalance significativo en la variable respuesta "Attrition", que es, en este caso, binaria. Al lanzar nuestro segundo modelo, hemos detectado que esto causa que el modelo sea incapaz de predecir correctamente cuándo se marchará un empleado de la empresa.
#
# - Para gestionar el desbalanceo, tenemos a nuestra disposición las herramientas de la librería "imblearn", que nos ayudan a equilibrar la categoría mayoría y minoritaria a través de la creación de "hijos" basados en las características de sus vecinos con *SMOTE_NC*, y reduciendo la cantidad de datos con *TomekLink*, que identifica pares de muestras de diferentes clases que son mutuamente las más cercanas, y elimina normalmente la muestra mayoritaria.
#
# - Como primer paso, separamos la "X" y la "y" del conjunto de datos.

# %%
df = df_standard
X = df.drop(columns = "Attrition")
y = df["Attrition"]

# %% [markdown]
# - Aplicaremos primero el método TomekLinks, que nos permitirá reducir el tamaño de la categoría mayoritaria, en este caso, "Attrition" con valor 0 (no).
#
# - Comprobaremos los cambios en el shape y los value counts de las categorías.

# %%
tomek = TomekLinks(sampling_strategy='auto', n_jobs=-1)
X_sampled, y_sampled = tomek.fit_resample(X, y)

resampled_df = pd.DataFrame(X_sampled, columns=X.columns)
resampled_df["Attrition"] = y_sampled

print(f'''Shape del DataFrame original: {df.shape}
Shape del DataFrame resampled: {resampled_df.shape}
Categoría "Attrition" original: {Counter(df["Attrition"])}
Categoría "Attrition" resampled: {Counter(resampled_df["Attrition"])}''')
# Out:
# Shape del DataFrame original: (1548, 25)
# Shape del DataFrame resampled: (1463, 25)
# Categoría "Attrition" original: Counter({'0': 1302, '1': 246})
# Categoría "Attrition" resampled: Counter({'0': 1217, '1': 246})

# %%
df.columns
# Out:
# Index(['Attrition', 'BusinessTravel', 'Department', 'Education',
#        'EducationField', 'Gender', 'JobLevel', 'JobRole', 'MaritalStatus',
#        'StockOptionLevel', 'TrainingTimesLastYear', 'EnvironmentSatisfaction',
#        'JobSatisfaction', 'WorkLifeBalance', 'JobInvolvement',
#        'PerformanceRating', 'Age_standard', 'DistanceFromHome_standard',
#        'MonthlyIncome_standard', 'NumCompaniesWorked_standard',
#        'PercentSalaryHike_standard', 'TotalWorkingYears_standard',
#        'YearsAtCompany_standard', 'YearsSinceLastPromotion_standard',
#        'YearsWithCurrManager_standard'],
#       dtype='object')

# %% [markdown]
# - Habiendo reducido la dimensión del desbalanceo eliminando las muestras cercanas en la categoría mayoritaria -los no-, necesitamos ahora aumentar la categoría minoritaria, los sí.
#
# - Para ello, necesitaremos indicar a al método SMOTENC aquellas features (variables) categóricas en que no queremos que aumente el número de categorías, dado que, serían ficticias. Por ejemplo, para la columna "Gender", sólo puede existir Male y Female, pero, al estar codificada numéricamente, podría crear nuevas categorías que no podrían mapearse de vuelta a otro valor.
#
# - Parte de los parámetros que pasar a SMOTENC es cuánto queremos que gestione el desbalanceo, a través del "sampling_strategy", cuando más cercano a uno, igualará las categorías, y creará más datos ficticios, aumentando el tamaño total del dataset.

# %%
lista_cat = ['EnvironmentSatisfaction', 'JobSatisfaction', 'WorkLifeBalance', 'BusinessTravel', 'Department', 'Education',
'EducationField', 'JobLevel', 'MaritalStatus', 'StockOptionLevel', 'TrainingTimesLastYear', 'JobInvolvement',
'PerformanceRating', 'NumCompaniesWorked_standard', 'PercentSalaryHike_standard', 'TotalWorkingYears_standard',
       'YearsAtCompany_standard', 'YearsSinceLastPromotion_standard',
       'YearsWithCurrManager_standard', 'Gender']

smotenc = SMOTENC(categorical_features=lista_cat, random_state=42, k_neighbors=5, sampling_strategy=1) 
X_resampled, y_resampled = smotenc.fit_resample(df, y)

resampled_data = pd.DataFrame(X_resampled, columns=df.columns)
resampled_data['Attrition'] = y_resampled

resampled_data.head(1)
# Out:
#   Attrition     BusinessTravel         Department          Education  \
# 0         0  0.159846547314578  0.159846547314578  0.159846547314578
#
#       EducationField             Gender           JobLevel   JobRole  \
# 0  0.159846547314578  0.159846547314578  0.159846547314578  0.159847
#
#        MaritalStatus   StockOptionLevel TrainingTimesLastYear  \
# 0  0.159846547314578  0.159846547314578     0.159846547314578
#
#   EnvironmentSatisfaction    JobSatisfaction    WorkLifeBalance  \
# 0       0.159846547314578  0.159846547314578  0.159846547314578
#
#       JobInvolvement  PerformanceRating  Age_standard  \
# 0  0.159846547314578  0.159846547314578      1.582686
#
#    DistanceFromHome_standard  MonthlyIncome_standard  \
# 0                  -0.385842                1.414871
#
#    NumCompaniesWorked_standard  PercentSalaryHike_standard  \
# 0                    -0.675545                   -1.150205
#
#    TotalWorkingYears_standard  YearsAtCompany_standard  \
# 0                   -1.341939                -1.007981
#
#    YearsSinceLastPromotion_standard  YearsWithCurrManager_standard
# 0                         -0.689743                      -1.153463

# %% [markdown]
# - En esta segunda iteración, utilizamos una estrategia de 1, que ha cambiado el desbalanceo de un original 84-16 a 53-47% en la variable respuesta.

# %%
ratio_vr = resampled_data["Attrition"].value_counts(normalize=True) * 100
print(f'''Ratio de Variable Respuesta:
      {ratio_vr}''')
# Out:
# Ratio de Variable Respuesta:
#       Attrition
# 0    50.0
# 1    50.0
# Name: proportion, dtype: float64

# %% [markdown]
# - Finalmente, guardamos el DF estandarizado al que aplicaremos los modelos predictivos.

# %%
with open('../../datos/pickles_transformados/modelo5/df_estandarizado.pkl', 'wb') as f:
    pickle.dump(resampled_data, f)
